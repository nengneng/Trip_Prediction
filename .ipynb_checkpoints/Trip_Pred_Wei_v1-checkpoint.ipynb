# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import sklearn
from sklearn import linear_model
from sklearn.cross_validation import train_test_split
from sklearn.feature_selection import RFE
from sklearn.preprocessing import OneHotEncoder, scale, LabelEncoder
from sklearn.metrics import mean_squared_error, r2_score

# %% [markdown]
# ## Load data

# %%
Train_raw = pd.read_csv(r'D:\Learn\HomeWork_Lyft\train.csv')
Test_raw = pd.read_csv(r'D:\Learn\HomeWork_Lyft\test.csv')

# %% [markdown]
# ## check data

# %%
Train_raw.head()
# Out:
#    row_id  start_lng  start_lat    end_lng    end_lat  start_timestamp  \
# 0       0 -74.009087  40.713818 -74.004326  40.719986       1420950819
# 1       1 -73.971176  40.762428 -74.004181  40.742653       1420950819
# 2       2 -73.994957  40.745079 -73.999939  40.734650       1421377541
# 3       3 -73.991127  40.750080 -73.988609  40.734890       1421377542
# 4       4 -73.945511  40.773724 -73.987434  40.755707       1422173586
#
#    duration
# 0       112
# 1      1159
# 2       281
# 3       636
# 4       705

# %%
len(Train_raw)
# Out:
# 12905715

# %%
Train_raw.dtypes
# Out:
# row_id               int64
# start_lng          float64
# start_lat          float64
# end_lng            float64
# end_lat            float64
# start_timestamp      int64
# duration             int64
# dtype: object

# %%
def num_missing(x):
    return len(x.index)-x.count()

def num_unique(x):
    return len(np.unique(x))

temp_df = Train_raw.describe().T
missing_df = pd.DataFrame(Train_raw.apply(num_missing, axis=0)) 
missing_df.columns = ['missing']
unq_df = pd.DataFrame(Train_raw.apply(num_unique, axis=0))
unq_df.columns = ['unique']
types_df = pd.DataFrame(Train_raw.dtypes)
types_df.columns = ['DataType']

# %%
summary_df = temp_df.join(missing_df).join(unq_df).join(types_df)
summary_df
# Out:
#                       count          mean           std           min  \
# row_id           12905715.0  6.452857e+06  3.725559e+06  0.000000e+00
# start_lng        12905715.0 -7.397382e+01  3.800296e-02 -7.451462e+01
# start_lat        12905715.0  4.075065e+01  2.789741e-02  4.036892e+01
# end_lng          12905715.0 -7.397358e+01  3.589918e-02 -7.451785e+01
# end_lat          12905715.0  4.075141e+01  3.192092e-02  4.036887e+01
# start_timestamp  12905715.0  1.435380e+09  9.079600e+06  1.420099e+09
# duration         12905715.0  8.421420e+02  7.127489e+02  1.000000e+00
#
#                           25%           50%           75%           max  \
# row_id           3.226428e+06  6.452857e+06  9.679286e+06  1.290571e+07
# start_lng       -7.399206e+01 -7.398196e+01 -7.396774e+01 -7.341445e+01
# start_lat        4.073697e+01  4.075359e+01  4.076792e+01  4.103142e+01
# end_lng         -7.399143e+01 -7.398009e+01 -7.396351e+01 -7.341435e+01
# end_lat          4.073552e+01  4.075408e+01  4.076905e+01  4.103151e+01
# start_timestamp  1.427509e+09  1.434868e+09  1.443342e+09  1.451635e+09
# duration         4.000000e+02  6.650000e+02  1.076000e+03  4.317800e+04
#
#                  missing    unique DataType
# row_id                 0  12905715    int64
# start_lng              0     36409  float64
# start_lat              0     63167  float64
# end_lng                0     55179  float64
# end_lat                0     88017  float64
# start_timestamp        0  10219862    int64
# duration               0      9485    int64

# %%
Test_raw.head()
# Out:
#    row_id  start_lng  start_lat    end_lng    end_lat  start_timestamp
# 0       0 -73.993111  40.724289 -74.000977  40.735222       1422173589
# 1       1 -73.971924  40.762749 -73.965698  40.771427       1420567340
# 2       2 -73.953247  40.765816 -73.952843  40.772453       1420567343
# 3       3 -73.986618  40.739353 -73.949158  40.805161       1420103336
# 4       4 -73.968864  40.757317 -73.982521  40.771305       1420690180

# %%
len(Test_raw)
# Out:
# 1434344

# %%
Train_raw['duration'].describe()
# Out:
# count    1.290572e+07
# mean     8.421420e+02
# std      7.127489e+02
# min      1.000000e+00
# 25%      4.000000e+02
# 50%      6.650000e+02
# 75%      1.076000e+03
# max      4.317800e+04
# Name: duration, dtype: float64

# %% [markdown]
# ## Create Features Based on trip start time

# %%
Train_raw['start_datetime'] = Train_raw['start_timestamp'].astype('int').astype("datetime64[s]")

Train_raw['start_year'] = Train_raw['start_datetime'].dt.year
Train_raw['start_month'] = Train_raw['start_datetime'].dt.month
Train_raw['start_day'] = Train_raw['start_datetime'].dt.day
Train_raw['start_dayOfWeek'] = Train_raw['start_datetime'].dt.dayofweek
Train_raw['start_hour'] = Train_raw['start_datetime'].dt.hour
Train_raw['start_minute'] = Train_raw['start_datetime'].dt.minute


#DayOfWeek (Monday = 0, Sunday = 6)
Train_raw.loc[Train_raw['start_dayOfWeek'].isin([5, 6]), 'start_isWeekend'] = 1 
Train_raw.loc[Train_raw['start_dayOfWeek'].isin([0, 1, 2, 3, 4]), 'start_isWeekend'] = 0

from pandas.tseries.holiday import USFederalHolidayCalendar as calendar
cal = calendar()
holidays = cal.holidays(start=Train_raw['start_datetime'].min(), end=Train_raw['start_datetime'].max())
Train_raw['start_isHoliday'] = np.where(Train_raw.start_datetime.dt.normalize().isin(holidays), 1, 0)

# %%
Train_raw.head()
# Out:
#    row_id  start_lng  start_lat    end_lng    end_lat  start_timestamp  \
# 0       0 -74.009087  40.713818 -74.004326  40.719986       1420950819
# 1       1 -73.971176  40.762428 -74.004181  40.742653       1420950819
# 2       2 -73.994957  40.745079 -73.999939  40.734650       1421377541
# 3       3 -73.991127  40.750080 -73.988609  40.734890       1421377542
# 4       4 -73.945511  40.773724 -73.987434  40.755707       1422173586
#
#    duration      start_datetime  start_year  start_month  start_day  \
# 0       112 2015-01-11 04:33:39        2015            1         11
# 1      1159 2015-01-11 04:33:39        2015            1         11
# 2       281 2015-01-16 03:05:41        2015            1         16
# 3       636 2015-01-16 03:05:42        2015            1         16
# 4       705 2015-01-25 08:13:06        2015            1         25
#
#    start_dayOfWeek  start_hour  start_minute  start_isWeekend  start_isHoliday
# 0                6           4            33              1.0                0
# 1                6           4            33              1.0                0
# 2                4           3             5              0.0                0
# 3                4           3             5              0.0                0
# 4                6           8            13              1.0                0

# %%
Train_raw['start_year'].value_counts()/Train_raw['start_year'].value_counts().sum()
# Out:
# 2015    0.998889
# 2016    0.001111
# Name: start_year, dtype: float64

# %%
Train_raw['start_month'].value_counts()/Train_raw['start_month'].value_counts().sum()
# Out:
# 3     0.091410
# 5     0.090644
# 4     0.089387
# 1     0.086480
# 2     0.084926
# 10    0.084388
# 6     0.084249
# 7     0.079273
# 12    0.078379
# 11    0.077472
# 9     0.076769
# 8     0.076624
# Name: start_month, dtype: float64

# %%
Train_raw['start_day'].value_counts()/Train_raw['start_day'].value_counts().sum()
# Out:
# 18    0.035058
# 19    0.034651
# 11    0.034459
# 8     0.034245
# 15    0.034129
# 20    0.034052
# 17    0.033962
# 12    0.033893
# 1     0.033863
# 14    0.033779
# 13    0.033742
# 10    0.033605
# 22    0.033414
# 21    0.033382
# 16    0.033263
# 7     0.033176
# 24    0.032597
# 3     0.032592
# 9     0.032543
# 6     0.032326
# 4     0.032025
# 25    0.031913
# 23    0.031889
# 5     0.031635
# 28    0.031334
# 2     0.031211
# 26    0.030509
# 30    0.029308
# 29    0.029267
# 27    0.028789
# 31    0.019390
# Name: start_day, dtype: float64

# %%
Train_raw['start_dayOfWeek'].value_counts()/Train_raw['start_dayOfWeek'].value_counts().sum()
# Out:
# 5    0.155736
# 6    0.151436
# 4    0.150238
# 3    0.147581
# 2    0.142000
# 1    0.131846
# 0    0.121163
# Name: start_dayOfWeek, dtype: float64

# %%
Train_raw['start_hour'].value_counts()/Train_raw['start_hour'].value_counts().sum()
# Out:
# 2     0.061415
# 3     0.059703
# 4     0.058329
# 5     0.056617
# 1     0.056448
# 6     0.051506
# 21    0.050242
# 22    0.049105
# 20    0.049088
# 19    0.048637
# 0     0.047472
# 18    0.046494
# 17    0.045643
# 16    0.045560
# 23    0.044554
# 15    0.042333
# 7     0.041763
# 14    0.031857
# 8     0.031436
# 9     0.023139
# 13    0.018348
# 10    0.017018
# 11    0.012530
# 12    0.010763
# Name: start_hour, dtype: float64

# %%
duration_by_hour = Train_raw.groupby(['start_hour'], as_index=False)['duration'].mean()
duration_by_dayOfWeek = Train_raw.groupby(['start_dayOfWeek'], as_index=False)['duration'].mean()

# %%
duration_by_dayOfWeek_hour = Train_raw.groupby(['start_dayOfWeek','start_hour'], as_index=False)['duration'].mean()

# %%
duration_by_dayOfWeek_hour
# Out:
#      start_dayOfWeek  start_hour    duration
# 0                  0           0  893.899883
# 1                  0           1  856.125435
# 2                  0           2  808.768081
# 3                  0           3  774.505633
# 4                  0           4  751.909913
# 5                  0           5  742.990705
# 6                  0           6  733.449686
# 7                  0           7  715.814014
# 8                  0           8  695.927638
# 9                  0           9  682.188685
# 10                 0          10  689.921229
# 11                 0          11  729.029542
# 12                 0          12  739.662612
# 13                 0          13  699.968754
# 14                 0          14  757.779743
# 15                 0          15  847.358813
# 16                 0          16  877.813825
# 17                 0          17  883.962033
# 18                 0          18  878.532654
# 19                 0          19  865.876232
# 20                 0          20  868.748957
# 21                 0          21  903.861979
# 22                 0          22  936.528966
# 23                 0          23  925.593831
# 24                 1           0  893.748085
# 25                 1           1  825.959290
# 26                 1           2  746.989095
# 27                 1           3  712.654522
# 28                 1           4  712.768800
# 29                 1           5  726.787753
# ..               ...         ...         ...
# 138                5          18  716.726513
# 139                5          19  753.544619
# 140                5          20  788.284802
# 141                5          21  817.884034
# 142                5          22  841.911798
# 143                5          23  841.398335
# 144                6           0  852.262510
# 145                6           1  842.582058
# 146                6           2  838.165782
# 147                6           3  821.959558
# 148                6           4  801.992965
# 149                6           5  810.455620
# 150                6           6  829.274004
# 151                6           7  807.999138
# 152                6           8  787.488191
# 153                6           9  720.080504
# 154                6          10  712.726319
# 155                6          11  723.154071
# 156                6          12  734.638383
# 157                6          13  726.850564
# 158                6          14  670.283595
# 159                6          15  628.801043
# 160                6          16  613.877518
# 161                6          17  635.883126
# 162                6          18  677.625988
# 163                6          19  734.167813
# 164                6          20  782.850054
# 165                6          21  849.258536
# 166                6          22  889.343588
# 167                6          23  901.720012
#
# [168 rows x 3 columns]

# %%
plt.bar(duration_by_hour['start_hour'], duration_by_hour['duration'], align='center', alpha=0.5)
plt.xticks(duration_by_hour['start_hour'], np.arange(len(duration_by_hour['start_hour'])))
plt.ylabel('Average Duration')
plt.xlabel('Trip Start Hour')
plt.title('Average Duration Vs Hour')

plt.show()

# %%
plt.bar(duration_by_dayOfWeek['start_dayOfWeek'], duration_by_dayOfWeek['duration'], align='center', alpha=0.5)
plt.xticks(duration_by_dayOfWeek['start_dayOfWeek'], np.arange(len(duration_by_dayOfWeek['start_dayOfWeek'])))

plt.ylabel('Average Duration')
plt.xlabel('Trip Start Day of Week: Monday = 0, Sunday = 6')
plt.title('Average Duration Vs Trip Start Day of Week')
 
plt.show()

# %%
Features_list = ['start_dayOfWeek',  'start_hour']
TrainFeatures = Train_raw.loc[:,Features_list]          
TrainFeatures[Features_list] = TrainFeatures[Features_list].astype(object)

# %%
TrainFeatures.head()
# Out:
#   start_dayOfWeek start_hour
# 0               6          4
# 1               6          4
# 2               4          3
# 3               4          3
# 4               6          8

# %%
X_train, X_test, Y_train, Y_test= train_test_split(TrainFeatures, Train_raw['duration'], test_size=0.3, random_state=2017)

print(len(X_train), len(X_test), len(Y_train), len(Y_test))

lm = linear_model.LinearRegression()
lm.fit(X_train[Features_list], Y_train)

predict_train = lm.predict(X_train[Features_list])
predict_test = lm.predict(X_test[Features_list])
# Out:
# 9034000 3871715 9034000 3871715

# %%
print("Mean squared error for train: %.2f" % mean_squared_error(Y_train, predict_train))
print("Mean squared error for test: %.2f" % mean_squared_error(Y_test, predict_test))
# Out:
# Mean squared error for train: 505026.79
# Mean squared error for test: 510347.96
